# %% [markdown]
# <a href="https://colab.research.google.com/github/RoxyDevs/Fooocus/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !pip install pygit2==1.15.1
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# /content
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 15.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.19.3
#     Uninstalling pygit2-1.19.3:
#       Successfully uninstalled pygit2-1.19.3
# ...
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6735, done.
# remote: Total 6735 (delta 0), reused 0 (delta 0), pack-reused 6735 (from 1)
# Receiving objects: 100% (6735/6735), 33.35 MiB | 26.79 MiB/s, done.
# Resolving deltas: 100% (3849/3849), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# /content/Fooocus/build_launcher.py:9: SyntaxWarning: invalid escape sequence '\p'
#   .\python_embeded\python.exe -s Fooocus\entry_with_update.py {cmds} %*
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# ...

# %%
import torch
if torch.cuda.is_available():
    print(f"GPU detectada: {torch.cuda.get_device_name(0)}")
else:
    print("ADVERTENCIA: No se detectó ninguna GPU. Asegúrate de activar el acelerador T4 en la configuración del entorno.")
# Out:
# ADVERTENCIA: No se detectó ninguna GPU. Asegúrate de activar el acelerador T4 en la configuración del entorno.

# %%
import os
os.kill(os.getpid(), 9)
